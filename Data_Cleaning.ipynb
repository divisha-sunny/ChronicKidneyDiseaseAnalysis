# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
blood_pressure = pd.read_csv('C:/Users/chowd/Documents/NEU/3rd quarter/Data Mining Applications/Final_Project/Blood_Pressure.csv', encoding='Windows-1252')

# %%
blood_pressure.head()
# Out:
#    Patient_Number  Blood_Pressure_Abnormality  Level_of_Hemoglobin  \
# 0               1                           1                11.28
# 1               2                           0                 9.75
# 2               3                           1                10.79
# 3               4                           0                11.00
# 4               5                           1                14.17
#
#    Genetic_Pedigree_Coefficient  Age  BMI  Sex  Pregnancy  Smoking  \
# 0                          0.90   34   23    1        1.0        0
# 1                          0.23   54   33    1        NaN        0
# 2                          0.91   70   49    0        NaN        0
# 3                          0.43   71   50    0        NaN        0
# 4                          0.83   52   19    0        NaN        0
#
#    Physical_activity  salt_content_in_the_diet  alcohol_consumption_per_day  \
# 0              45961                     48071                          NaN
# ...

# %%
blood_pressure.shape
# Out:
# (2000, 15)

# %%
blood_pressure.describe()
# Out:
#        Patient_Number  Blood_Pressure_Abnormality  Level_of_Hemoglobin  \
# count     2000.000000                 2000.000000          2000.000000
# mean      1000.500000                    0.493500            11.710035
# std        577.494589                    0.500083             2.186701
# min          1.000000                    0.000000             8.100000
# 25%        500.750000                    0.000000            10.147500
# 50%       1000.500000                    0.000000            11.330000
# 75%       1500.250000                    1.000000            12.945000
# max       2000.000000                    1.000000            17.560000
#
#        Genetic_Pedigree_Coefficient          Age          BMI          Sex  \
# count                   1908.000000  2000.000000  2000.000000  2000.000000
# mean                       0.494817    46.558500    30.081500     0.496000
# std                        0.291736    17.107832    11.761208     0.500109
# ...

# %%
blood_pressure.dtypes
# Out:
# Patient_Number                     int64
# Blood_Pressure_Abnormality         int64
# Level_of_Hemoglobin              float64
# Genetic_Pedigree_Coefficient     float64
# Age                                int64
# BMI                                int64
# Sex                                int64
# Pregnancy                        float64
# Smoking                            int64
# Physical_activity                  int64
# salt_content_in_the_diet           int64
# alcohol_consumption_per_day      float64
# Level_of_Stress                    int64
# Chronic_kidney_disease             int64
# Adrenal_and_thyroid_disorders      int64
# dtype: object

# %%
missing_values = blood_pressure.isnull().sum()
missing_values
# Out:
# Patient_Number                      0
# Blood_Pressure_Abnormality          0
# Level_of_Hemoglobin                 0
# Genetic_Pedigree_Coefficient       92
# Age                                 0
# BMI                                 0
# Sex                                 0
# Pregnancy                        1558
# Smoking                             0
# Physical_activity                   0
# salt_content_in_the_diet            0
# alcohol_consumption_per_day       242
# Level_of_Stress                     0
# Chronic_kidney_disease              0
# Adrenal_and_thyroid_disorders       0
# dtype: int64

# %%
missing_values_count = blood_pressure.isnull().sum()

# Calculate the percentage of missing values in each column
percent_missing = (missing_values_count/len(blood_pressure)) * 100

# Combine the results into a DataFrame
missing_data = pd.concat([missing_values_count, percent_missing], axis=1, keys=['Total', 'Percent'])

# Print the results
print("Number and percentage of missing values for each column:\n", missing_data)
# Out:
# Number and percentage of missing values for each column:
#                                 Total  Percent
# Patient_Number                     0      0.0
# Blood_Pressure_Abnormality         0      0.0
# Level_of_Hemoglobin                0      0.0
# Genetic_Pedigree_Coefficient      92      4.6
# Age                                0      0.0
# BMI                                0      0.0
# Sex                                0      0.0
# Pregnancy                       1558     77.9
# Smoking                            0      0.0
# Physical_activity                  0      0.0
# salt_content_in_the_diet           0      0.0
# alcohol_consumption_per_day      242     12.1
# Level_of_Stress                    0      0.0
# Chronic_kidney_disease             0      0.0
# Adrenal_and_thyroid_disorders      0      0.0

# %%
not_missing_values = blood_pressure.count()

plt.subplots(figsize=(35, 6))
plt.bar(not_missing_values.index, not_missing_values.values)

for i, v in enumerate(not_missing_values.values):
    plt.text(i, v+10, str(v), ha='center')

# Set the title and labels
plt.title('Non-Missing Values')
plt.xlabel('Columns')
plt.ylabel('Number of Non- Missing Values')

# Show the plot
plt.show()

# %%
blood_pressure.duplicated().sum()
# Out:
# 0

# %%
blood_pressure.columns
# Out:
# Index(['Patient_Number', 'Blood_Pressure_Abnormality', 'Level_of_Hemoglobin',
#        'Genetic_Pedigree_Coefficient', 'Age', 'BMI', 'Sex', 'Pregnancy',
#        'Smoking', 'Physical_activity', 'salt_content_in_the_diet',
#        'alcohol_consumption_per_day', 'Level_of_Stress',
#        'Chronic_kidney_disease', 'Adrenal_and_thyroid_disorders'],
#       dtype='object')

# %%
blood_pressure[blood_pressure.columns[1:]].corr()
# Out:
#                                Blood_Pressure_Abnormality  \
# Blood_Pressure_Abnormality                       1.000000
# Level_of_Hemoglobin                              0.139488
# Genetic_Pedigree_Coefficient                    -0.033458
# Age                                             -0.066322
# BMI                                              0.040193
# Sex                                              0.054902
# Pregnancy                                       -0.017331
# Smoking                                          0.012250
# Physical_activity                                0.037952
# salt_content_in_the_diet                         0.014199
# alcohol_consumption_per_day                      0.020773
# Level_of_Stress                                  0.009304
# Chronic_kidney_disease                           0.429188
# Adrenal_and_thyroid_disorders                    0.318598
#
#                                Level_of_Hemoglobin  \
# ...

# %%
#Replacing the Genetic_Pedigree_Coefficient with mean value
mean_value = blood_pressure['Genetic_Pedigree_Coefficient'].mean()
blood_pressure['Genetic_Pedigree_Coefficient'].fillna(mean_value, inplace=True)

# %%
import math
import matplotlib.pyplot as plt

# Define blood_pressure variable
#blood_pressure = ...

# Determine number of rows and columns for subplots
variables = ['Level_of_Hemoglobin', 'Genetic_Pedigree_Coefficient', 'Age', 'BMI', 'Physical_activity', 'salt_content_in_the_diet']
num_plots = len(variables)
num_cols = 3
num_rows = int(math.ceil(num_plots/num_cols))

# Set figure size
fig, axs = plt.subplots(num_rows, num_cols, figsize=(20, num_rows*4))

# Loop through each variable and create scatter plots
for i, var in enumerate(variables):
    row = i // num_cols
    col = i % num_cols + 1  # start from 2nd column
    axs[row, col-1].scatter(blood_pressure['alcohol_consumption_per_day'], blood_pressure[var])
    axs[row, col-1].set_xlabel('Alcohol consumption per day')
    axs[row, col-1].set_ylabel(var)
    axs[row, col-1].set_title(var)

# Hide empty subplots
for i in range(num_plots, num_rows*num_cols):
    row = i // num_cols
    col = i % num_cols + 1  # start from 2nd column
    axs[row, col-1].set_visible(False)

plt.tight_layout()
plt.show()

# %%
blood_pressure.loc[blood_pressure['Sex'] == 0, 'Pregnancy']
# Out:
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 7      NaN
#         ..
# 1989   NaN
# 1990   NaN
# 1991   NaN
# 1997   NaN
# 1999   NaN
# Name: Pregnancy, Length: 1008, dtype: float64

# %%
#Replacing the missing values of pregnancy
blood_pressure.loc[(blood_pressure['Sex'] == 0) & (blood_pressure['Pregnancy'].isnull()), 'Pregnancy'] = 0

# %%
blood_pressure.loc[blood_pressure['Sex'] == 1, 'Pregnancy']
# Out:
# 0       1.0
# 1       NaN
# 6       1.0
# 10      NaN
# 15      1.0
#        ...
# 1993    NaN
# 1994    NaN
# 1995    NaN
# 1996    1.0
# 1998    NaN
# Name: Pregnancy, Length: 992, dtype: float64

# %%
blood_pressure.loc[(blood_pressure['Sex'] == 1) & (blood_pressure['Age'] > 45)]
# Out:
#       Patient_Number  Blood_Pressure_Abnormality  Level_of_Hemoglobin  \
# 1                  2                           0                 9.75
# 10                11                           1                 8.58
# 16                17                           1                11.98
# 21                22                           0                10.85
# 22                23                           0                11.19
# ...              ...                         ...                  ...
# 1992            1993                           1                 9.38
# 1993            1994                           0                 9.69
# 1994            1995                           0                11.07
# 1995            1996                           1                10.14
# 1998            1999                           0                11.15
#
#       Genetic_Pedigree_Coefficient  Age  BMI  Sex  Pregnancy  Smoking  \
# ...

# %%
blood_pressure.loc[(blood_pressure['Sex'] == 1) & (blood_pressure['Age'] >= 45), 'Pregnancy'] = 0

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor

# Split the dataset into train and test sets
train = blood_pressure[blood_pressure['alcohol_consumption_per_day'].notnull()]
test = blood_pressure[blood_pressure['alcohol_consumption_per_day'].isnull()]

# Define the features and target variable
features = ['Blood_Pressure_Abnormality', 'Level_of_Hemoglobin', 'Genetic_Pedigree_Coefficient', 'Age', 'BMI', 'Sex',
            'Pregnancy', 'Smoking', 'Physical_activity', 'salt_content_in_the_diet', 'Level_of_Stress',
            'Adrenal_and_thyroid_disorders']
target = 'alcohol_consumption_per_day'

# Create random forest model
rf_model = RandomForestRegressor()
rf_model.fit(train[features], train[target])

# Fill the missing values using random forest model
blood_pressure.loc[blood_pressure['alcohol_consumption_per_day'].isnull(), 'alcohol_consumption_per_day'] = rf_model.predict(blood_pressure.loc[blood_pressure['alcohol_consumption_per_day'].isnull(), features])

# %%
blood_pressure.isnull().sum()
# Out:
# Patient_Number                   0
# Blood_Pressure_Abnormality       0
# Level_of_Hemoglobin              0
# Genetic_Pedigree_Coefficient     0
# Age                              0
# BMI                              0
# Sex                              0
# Pregnancy                        0
# Smoking                          0
# Physical_activity                0
# salt_content_in_the_diet         0
# alcohol_consumption_per_day      0
# Level_of_Stress                  0
# Chronic_kidney_disease           0
# Adrenal_and_thyroid_disorders    0
# dtype: int64

# %%
columns = list(blood_pressure.columns)

# Create a box plot for each column
for col in columns:
    fig, ax = plt.subplots()
    ax.boxplot(blood_pressure[col])
    ax.set_title(col)
    ax.set_ylabel('Values')
    plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a figure with 5 subplots in one row
fig, axs = plt.subplots(nrows=1, ncols=5, figsize=(20, 5))

# Generate box plots for each column
for col, ax in zip(blood_pressure.columns, axs):
    ax.boxplot(blood_pressure[col])
    ax.set_title(col)

# Show the plot
plt.show()

# %%
import pandas as pd

# Find the outliers for each column
for column in blood_pressure.columns:
    q1 = blood_pressure[column].quantile(0.25)
    q3 = blood_pressure[column].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    outliers = blood_pressure[(blood_pressure[column] < lower_bound) | (blood_pressure[column] > upper_bound)][column]
    print(f"Outliers in {column}: {outliers.tolist()}")
# Out:
# Outliers in Patient_Number: []
# Outliers in Blood_Pressure_Abnormality: []
# Outliers in Level_of_Hemoglobin: [17.51, 17.3, 17.52, 17.52, 17.31, 17.45, 17.44, 17.54, 17.39, 17.48, 17.44, 17.32, 17.2, 17.15, 17.35, 17.44, 17.56, 17.22, 17.15, 17.53, 17.17]
# Outliers in Genetic_Pedigree_Coefficient: []
# Outliers in Age: []
# Outliers in BMI: []
# Outliers in Sex: []
# ...

# %%
import numpy as np
from scipy.stats.mstats import winsorize
blood_pressure['Level_of_Hemoglobin'] = winsorize(blood_pressure['Level_of_Hemoglobin'], limits=[0.02, 0.02])

# %%
import matplotlib.pyplot as plt

hemoglobin_data = blood_pressure['Level_of_Hemoglobin']
plt.boxplot(hemoglobin_data)
plt.title("Boxplot of Level of Hemoglobin")
plt.show()

# %%
blood_pressure.dtypes
# Out:
# Patient_Number                     int64
# Blood_Pressure_Abnormality         int64
# Level_of_Hemoglobin              float64
# Genetic_Pedigree_Coefficient     float64
# Age                                int64
# BMI                                int64
# Sex                                int64
# Pregnancy                          int32
# Smoking                            int64
# Physical_activity                  int64
# salt_content_in_the_diet           int64
# alcohol_consumption_per_day      float64
# Level_of_Stress                    int64
# Chronic_kidney_disease             int64
# Adrenal_and_thyroid_disorders      int64
# dtype: object

# %%
blood_pressure['Pregnancy'] = blood_pressure['Pregnancy'].astype(int)

# %%
blood_pressure.isnull().sum()
# Out:
# Patient_Number                   0
# Blood_Pressure_Abnormality       0
# Level_of_Hemoglobin              0
# Genetic_Pedigree_Coefficient     0
# Age                              0
# BMI                              0
# Sex                              0
# Pregnancy                        0
# Smoking                          0
# Physical_activity                0
# salt_content_in_the_diet         0
# alcohol_consumption_per_day      0
# Level_of_Stress                  0
# Chronic_kidney_disease           0
# Adrenal_and_thyroid_disorders    0
# dtype: int64

# %%
blood_pressure.to_csv('blood_pressure_cleaned.csv', index=False)

# %%
blood_pressure.head()
# Out:
#    Patient_Number  Blood_Pressure_Abnormality  Level_of_Hemoglobin  \
# 0               1                           1                11.28
# 1               2                           0                 9.75
# 2               3                           1                10.79
# 3               4                           0                11.00
# 4               5                           1                14.17
#
#    Genetic_Pedigree_Coefficient  Age  BMI  Sex  Pregnancy  Smoking  \
# 0                          0.90   34   23    1        1.0        0
# 1                          0.23   54   33    1        0.0        0
# 2                          0.91   70   49    0        0.0        0
# 3                          0.43   71   50    0        0.0        0
# 4                          0.83   52   19    0        0.0        0
#
#    Physical_activity  salt_content_in_the_diet  alcohol_consumption_per_day  \
# 0              45961                     48071                       227.08
# ...

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=blood_pressure, x='Age', kde=True, color='red', bins=15)
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Distribution of Age')
plt.show()
